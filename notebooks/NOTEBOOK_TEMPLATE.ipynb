# %% [markdown]
# # Experiment: [Title]
#
# **Date:** YYYY-MM-DD
# **Author:**
# **Research question:** RQx
#
# ## Objective
#
# [What this experiment aims to investigate]
#
# ## Hypothesis
#
# [Expected outcome and reasoning]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mlflow

from src.machinability.utils.config import REPO_ROOT, MLFLOW_TRACKING_URI, MLFLOW_EXPERIMENT_NAME
from src.machinability.data.loader import load_evidence_matrix

mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
mlflow.set_experiment(MLFLOW_EXPERIMENT_NAME)

# %matplotlib inline
sns.set_theme(style='whitegrid', palette='colorblind')

# %% [markdown]
# ## 1. Data Loading

# %%
# Load data
# df = load_evidence_matrix()
# df.head()

# %% [markdown]
# ## 2. Exploratory Analysis

# %%
# Exploratory plots and statistics

# %% [markdown]
# ## 3. Method / Model

# %%
# with mlflow.start_run(run_name="experiment-name"):
#     mlflow.log_params({...})
#     # model training / analysis
#     mlflow.log_metrics({...})

# %% [markdown]
# ## 4. Results

# %%
# Results visualization

# %% [markdown]
# ## 5. Conclusions
#
# - **Finding 1:** ...
# - **Finding 2:** ...
#
# ### Next steps
#
# - [ ] ...
